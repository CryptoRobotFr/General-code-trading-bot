# %%
# pip install ccxt pandas pydantic ta
from typing import List, Optional
import ccxt.async_support as ccxt
import pandas as pd
from pydantic import BaseModel
from decimal import Decimal, getcontext, ROUND_DOWN
import math
import ta
import time

# %%
class UsdtBalance(BaseModel):
    total: float
    free: float
    used: float


class Info(BaseModel):
    success: bool
    message: str


class Order(BaseModel):
    id: str
    pair: str
    type: str
    side: str
    price: float
    size: float
    reduce: bool
    filled: float
    remaining: float
    timestamp: int


class TriggerOrder(BaseModel):
    id: str
    pair: str
    type: str
    side: str
    price: float
    trigger_price: float
    size: float
    reduce: bool
    timestamp: int


class Position(BaseModel):
    pair: str
    side: str
    size: float
    usd_size: float
    entry_price: float
    current_price: float
    unrealized_pnl: float
    liquidation_price: float
    margin_mode: str
    leverage: int
    hedge_mode: bool
    open_timestamp: int = 0
    take_profit_price: float | None = None
    stop_loss_price: float | None = None

class Market(BaseModel):
    internal_pair: str
    base: str
    quote: str
    price_precision: float
    contract_precision: float
    contract_size: Optional[float] = 1.0
    min_contracts: float
    max_contracts: Optional[float] = float('inf')
    min_cost: Optional[float] = 0.0
    max_cost: Optional[float] = float('inf')
    coin_index: Optional[int] = 0
    market_price: Optional[float] = 0.0


def get_price_precision(price: float) -> float:
    log_price = math.log10(price)
    order = math.floor(log_price)
    precision = 10 ** (order - 4)
    return precision
    
def number_to_str(n: float) -> str:
    s = format(n, 'f')
    s = s.rstrip('0')
    if s.endswith('.'):
        s = s[:-1]
    
    return s


class PerpHyperliquid:
    def __init__(self, public_adress=None, private_key=None):
        hyperliquid_auth_object = {
            "walletAddress": public_adress,
            "privateKey": private_key,
        }
        self.public_adress = public_adress
        getcontext().prec = 10
        if hyperliquid_auth_object["privateKey"] == None:
            self._auth = False
            self._session = ccxt.hyperliquid()
        else:
            self._auth = True
            self._session = ccxt.hyperliquid(hyperliquid_auth_object)
        self.market: dict[str, Market] = {}

    async def close(self):
        await self._session.close()

    async def load_markets(self) -> dict[str, Market]:
        data = await self._session.publicPostInfo(params={
            "type": "metaAndAssetCtxs",
        })
        resp = {}
        for i in range(0,len(data[0]["universe"])):
            mark_price = float(data[1][i]["markPx"])
            object = data[0]["universe"][i]
            size_decimals = int(object["szDecimals"])
            resp[object["name"]+"/USD"] = Market(
                internal_pair=object["name"],
                base=object["name"],
                quote="USD",
                price_precision=get_price_precision(mark_price),
                contract_precision=1/(10**(size_decimals)),
                min_contracts=1/(10**(size_decimals)),
                min_cost=10,
                coin_index=i,
                market_price=mark_price,
            )
        self.market = resp
        return resp



    def ext_pair_to_pair(self, ext_pair) -> str:
        return self.market[ext_pair].internal_pair

    def pair_to_ext_pair(self, pair) -> str:
        return pair+"/USD"
    
    def ext_pair_to_base(self, ext_pair) -> str:
        return ext_pair.split("/")[0]

    def get_pair_info(self, ext_pair) -> str:
        pair = self.ext_pair_to_pair(ext_pair)
        if pair in self.market:
            return self.market[pair]
        else:
            return None
        
    def size_to_precision(self, pair: str, size: float) -> float:
        size_precision = self.market[pair].contract_precision
        decimal_precision = Decimal(str(size_precision))
        rounded_size = Decimal(str(size)).quantize(decimal_precision, rounding=ROUND_DOWN)
        return float(rounded_size)
    
    def price_to_precision(self, pair: str, price: float) -> float:
        price_precision = self.market[pair].price_precision
        price_dec = Decimal(str(price))
        precision_dec = Decimal(str(price_precision))
        
        rounded_price = (price_dec // precision_dec) * precision_dec
        
        return float(rounded_price)

    async def get_last_ohlcv(self, pair, timeframe, limit=1000) -> pd.DataFrame:
        if limit > 5000:
            limit = 5000
        base_pair = self.ext_pair_to_base(pair)
        ts_dict = {
            "1m": 1 * 60 * 1000,
            "5m": 5 * 60 * 1000,
            "15m": 15 * 60 * 1000,
            "1h": 60 * 60 * 1000,
            "2h": 2 * 60 * 60 * 1000,
            "4h": 4 * 60 * 60 * 1000,
            "1d": 24 * 60 * 60 * 1000,
        }
        end_ts = int(time.time() * 1000)
        start_ts = end_ts - ((limit-1) * ts_dict[timeframe])
        data = await self._session.publicPostInfo(params={
            "type": "candleSnapshot",
            "req": {
                "coin": base_pair,
                "interval": timeframe,
                "startTime": start_ts,
                "endTime": end_ts,
            },
        })
        df = pd.DataFrame(data)
        df['date'] = pd.to_datetime(df['t'].astype(float), unit='ms')
        df.set_index('date', inplace=True)
        df = df[['o', 'h', 'l', 'c', 'v']].astype(float)
        df.rename(columns={
            'o': 'open',
            'h': 'high',
            'l': 'low',
            'c': 'close',
            'v': 'volume'
        }, inplace=True)

        return df

    async def get_balance(self) -> UsdtBalance:
        data = await self._session.publicPostInfo(params={
            "type": "clearinghouseState",
            "user": self.public_adress,
        })
        total = float(data["marginSummary"]["accountValue"])
        used = float(data["marginSummary"]["totalMarginUsed"])
        free = total - used
        return UsdtBalance(
            total=total,
            free=free,
            used=used,
        )

    async def set_margin_mode_and_leverage(self, pair, margin_mode, leverage):
        if margin_mode not in ["cross", "isolated"]:
            raise Exception("Margin mode must be either 'cross' or 'isolated'")
        asset_index = self.market[pair].coin_index
        try:
            nonce = int(time.time() * 1000)
            req_body = {}
            action = {
                "type": "updateLeverage",
                "asset": asset_index,
                "isCross": margin_mode == "cross",
                "leverage": leverage,
            }
            signature = self._session.sign_l1_action(action, nonce)
            req_body["action"] = action
            req_body["nonce"] = nonce
            req_body["signature"] = signature
            await self._session.private_post_exchange(params=req_body)
        except Exception as e:
            raise e

        return Info(
            success=True,
            message=f"Margin mode and leverage set to {margin_mode} and {leverage}x",
        )

    async def get_open_positions(self, pairs=[]) -> List[Position]:
        data = await self._session.publicPostInfo(params={
            "type": "clearinghouseState",
            "user": self.public_adress,
        })
        # return data
        positions_data = data["assetPositions"]
        positions = []
        for position_data in positions_data:
            position = position_data["position"]
            if self.pair_to_ext_pair(position["coin"]) not in pairs and len(pairs) > 0:
                continue
            type_mode = position_data["type"]
            hedge_mode = True if type_mode != "oneWay" else False
            size = float(position["szi"])
            side = "long" if size > 0 else "short"
            size = abs(size)
            usd_size = float(position["positionValue"])
            current_price = usd_size / size
            positions.append(
                Position(
                    pair=self.pair_to_ext_pair(position["coin"]),
                    side=side,
                    size=size,
                    usd_size=usd_size,
                    entry_price=float(position["entryPx"]),
                    current_price=current_price,
                    unrealized_pnl=float(position["unrealizedPnl"]),
                    liquidation_price=float(position["liquidationPx"]),
                    margin_mode=position["leverage"]["type"],
                    leverage=position["leverage"]["value"],
                    hedge_mode=hedge_mode,
                )
            )

        return positions

    async def place_order(
        self,
        pair,
        side,
        price,
        size,
        type="limit",
        reduce=False,
        error=True,
        market_max_spread=0.1,
    ) -> Order:
        if price is None:
            price = self.market[pair].market_price
        try:
            asset_index = self.market[pair].coin_index
            nonce = int(time.time() * 1000)
            is_buy = side == "buy"
            req_body = {}
            if type == "market":
                if side == "buy":
                    price = price * (1 + market_max_spread)
                else:
                    price = price * (1 - market_max_spread)

            print(number_to_str(self.price_to_precision(pair, price)))
            action = {
                "type": "order",
                "orders": [{
                    "a": asset_index,
                    "b": is_buy,
                    "p": number_to_str(self.price_to_precision(pair, price)),
                    "s": number_to_str(self.size_to_precision(pair, size)),
                    "r": reduce,
                    "t": {"limit":{"tif": "Gtc"}}
                }],
                "grouping": "na",
                "brokerCode": 1,
            }
            signature = self._session.sign_l1_action(action, nonce)
            req_body["action"] = action
            req_body["nonce"] = nonce
            req_body["signature"] = signature
            resp = await self._session.private_post_exchange(params=req_body)
            
            order_resp = resp["response"]["data"]["statuses"][0]
            order_key = list(order_resp.keys())[0]
            order_id = resp["response"]["data"]["statuses"][0][order_key]["oid"]

            order = await self.get_order_by_id(order_id)

            if order_key == "filled":
                order_price = resp["response"]["data"]["statuses"][0][order_key]["avgPx"]
                order.price = float(order_price)
            
            return order
        except Exception as e:
            if error:
                raise e
            else:
                print(e)
                return None


    async def get_order_by_id(self, order_id) -> Order:
        order_id = int(order_id)
        data = await self._session.publicPostInfo(params={
            "user": self.public_adress,
            "type": "orderStatus",
            "oid": order_id,
        })
        order = data["order"]["order"]
        side_map = {
            "A": "sell",
            "B": "buy",
        }
        return Order(
            id=str(order_id),
            pair=self.pair_to_ext_pair(order["coin"]),
            type=order["orderType"].lower(),
            side=side_map[order["side"]],
            price=float(order["limitPx"]),
            size=float(order["origSz"]),
            reduce=order["reduceOnly"],
            filled=float(order["origSz"]) - float(order["sz"]),
            remaining=float(order["sz"]),
            timestamp=int(order["timestamp"]),
        )

    async def cancel_orders(self, pair, ids=[]):
        try:
            asset_index = self.market[pair].coin_index
            nonce = int(time.time() * 1000)
            req_body = {}
            orders_action = []
            for order_id in ids:
                orders_action.append({
                    "a": asset_index,
                    "o": int(order_id),
                })
            action = {
                "type": "cancel",
                "cancels": orders_action,
            }
            signature = self._session.sign_l1_action(action, nonce)
            req_body["action"] = action
            req_body["nonce"] = nonce
            req_body["signature"] = signature
            resp = await self._session.private_post_exchange(params=req_body)
            return Info(success=True, message=f"Orders cancelled")
        except Exception as e:
            return Info(success=False, message="Error or no orders to cancel")
# Out:
# hyperliquid requires to release all resources with an explicit call to the .close() coroutine. If you are using the exchange instance with async coroutines, add `await exchange.close()` to your code into a place when you're done with the exchange and don't need the exchange instance anymore (at the end of your async coroutine).
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000001597F471EE0>
# hyperliquid requires to release all resources with an explicit call to the .close() coroutine. If you are using the exchange instance with async coroutines, add `await exchange.close()` to your code into a place when you're done with the exchange and don't need the exchange instance anymore (at the end of your async coroutine).
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000001590F3B83E0>

# %%
ex = PerpHyperliquid(
    public_adress="",
    private_key="",
)
await ex.load_markets()
# Out:
# hyperliquid requires to release all resources with an explicit call to the .close() coroutine. If you are using the exchange instance with async coroutines, add `await exchange.close()` to your code into a place when you're done with the exchange and don't need the exchange instance anymore (at the end of your async coroutine).
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000001597EE19220>
# {'BTC/USD': Market(internal_pair='BTC', base='BTC', quote='USD', price_precision=10.0, contract_precision=1e-05, contract_size=1.0, min_contracts=1e-05, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=0, market_price=101110.0),
#  'ETH/USD': Market(internal_pair='ETH', base='ETH', quote='USD', price_precision=0.1, contract_precision=0.0001, contract_size=1.0, min_contracts=0.0001, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=1, market_price=3912.2),
#  'ATOM/USD': Market(internal_pair='ATOM', base='ATOM', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=2, market_price=10.061),
#  'MATIC/USD': Market(internal_pair='MATIC', base='MATIC', quote='USD', price_precision=1e-05, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=3, market_price=0.37621),
#  'DYDX/USD': Market(internal_pair='DYDX', base='DYDX', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=4, market_price=1.9091),
#  'SOL/USD': Market(internal_pair='SOL', base='SOL', quote='USD', price_precision=0.01, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=5, market_price=239.76),
#  'AVAX/USD': Market(internal_pair='AVAX', base='AVAX', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=6, market_price=53.227),
#  'BNB/USD': Market(internal_pair='BNB', base='BNB', quote='USD', price_precision=0.01, contract_precision=0.001, contract_size=1.0, min_contracts=0.001, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=7, market_price=734.34),
#  'APE/USD': Market(internal_pair='APE', base='APE', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=8, market_price=1.9496),
#  'OP/USD': Market(internal_pair='OP', base='OP', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=9, market_price=2.6178),
#  'LTC/USD': Market(internal_pair='LTC', base='LTC', quote='USD', price_precision=0.01, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=10, market_price=143.15),
#  'ARB/USD': Market(internal_pair='ARB', base='ARB', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=11, market_price=1.1567),
#  'DOGE/USD': Market(internal_pair='DOGE', base='DOGE', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=12, market_price=0.44252),
#  'INJ/USD': Market(internal_pair='INJ', base='INJ', quote='USD', price_precision=0.001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=13, market_price=33.864),
#  'SUI/USD': Market(internal_pair='SUI', base='SUI', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=14, market_price=4.1999),
#  'kPEPE/USD': Market(internal_pair='kPEPE', base='kPEPE', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=15, market_price=0.021914),
#  'CRV/USD': Market(internal_pair='CRV', base='CRV', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=16, market_price=1.1075),
#  'LDO/USD': Market(internal_pair='LDO', base='LDO', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=17, market_price=2.1609),
#  'LINK/USD': Market(internal_pair='LINK', base='LINK', quote='USD', price_precision=0.001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=18, market_price=24.475),
#  'STX/USD': Market(internal_pair='STX', base='STX', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=19, market_price=2.8177),
#  'RNDR/USD': Market(internal_pair='RNDR', base='RNDR', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=20, market_price=6.8952),
#  'CFX/USD': Market(internal_pair='CFX', base='CFX', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=21, market_price=0.24931),
#  'FTM/USD': Market(internal_pair='FTM', base='FTM', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=22, market_price=1.2699),
#  'GMX/USD': Market(internal_pair='GMX', base='GMX', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=23, market_price=37.447),
#  'SNX/USD': Market(internal_pair='SNX', base='SNX', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=24, market_price=3.0357),
#  'XRP/USD': Market(internal_pair='XRP', base='XRP', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=25, market_price=2.4215),
#  'BCH/USD': Market(internal_pair='BCH', base='BCH', quote='USD', price_precision=0.01, contract_precision=0.001, contract_size=1.0, min_contracts=0.001, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=26, market_price=613.4),
#  'APT/USD': Market(internal_pair='APT', base='APT', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=27, market_price=14.313),
#  'AAVE/USD': Market(internal_pair='AAVE', base='AAVE', quote='USD', price_precision=0.01, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=28, market_price=259.13),
#  'COMP/USD': Market(internal_pair='COMP', base='COMP', quote='USD', price_precision=0.01, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=29, market_price=123.93),
#  'MKR/USD': Market(internal_pair='MKR', base='MKR', quote='USD', price_precision=0.1, contract_precision=0.0001, contract_size=1.0, min_contracts=0.0001, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=30, market_price=2175.8),
#  'WLD/USD': Market(internal_pair='WLD', base='WLD', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=31, market_price=4.0185),
#  'FXS/USD': Market(internal_pair='FXS', base='FXS', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=32, market_price=4.6858),
#  'HPOS/USD': Market(internal_pair='HPOS', base='HPOS', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=33, market_price=0.28362),
#  'RLB/USD': Market(internal_pair='RLB', base='RLB', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=34, market_price=0.13437),
#  'UNIBOT/USD': Market(internal_pair='UNIBOT', base='UNIBOT', quote='USD', price_precision=0.0001, contract_precision=0.001, contract_size=1.0, min_contracts=0.001, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=35, market_price=7.636),
#  'YGG/USD': Market(internal_pair='YGG', base='YGG', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=36, market_price=0.82091),
#  'TRX/USD': Market(internal_pair='TRX', base='TRX', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=37, market_price=0.33238),
#  'kSHIB/USD': Market(internal_pair='kSHIB', base='kSHIB', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=38, market_price=0.031431),
#  'UNI/USD': Market(internal_pair='UNI', base='UNI', quote='USD', price_precision=0.001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=39, market_price=15.588),
#  'SEI/USD': Market(internal_pair='SEI', base='SEI', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=40, market_price=0.72933),
#  'RUNE/USD': Market(internal_pair='RUNE', base='RUNE', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=41, market_price=7.1726),
#  'OX/USD': Market(internal_pair='OX', base='OX', quote='USD', price_precision=1e-07, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=42, market_price=0.007459),
#  'FRIEND/USD': Market(internal_pair='FRIEND', base='FRIEND', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=43, market_price=4.72),
#  'SHIA/USD': Market(internal_pair='SHIA', base='SHIA', quote='USD', price_precision=1e-08, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=44, market_price=0.000621),
#  'CYBER/USD': Market(internal_pair='CYBER', base='CYBER', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=45, market_price=5.3265),
#  'ZRO/USD': Market(internal_pair='ZRO', base='ZRO', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=46, market_price=6.5281),
#  'BLZ/USD': Market(internal_pair='BLZ', base='BLZ', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=47, market_price=0.1872),
#  'DOT/USD': Market(internal_pair='DOT', base='DOT', quote='USD', price_precision=0.001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=48, market_price=11.034),
#  'BANANA/USD': Market(internal_pair='BANANA', base='BANANA', quote='USD', price_precision=0.001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=49, market_price=59.191),
#  'TRB/USD': Market(internal_pair='TRB', base='TRB', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=50, market_price=92.666),
#  'FTT/USD': Market(internal_pair='FTT', base='FTT', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=51, market_price=3.804),
#  'LOOM/USD': Market(internal_pair='LOOM', base='LOOM', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=52, market_price=0.081098),
#  'OGN/USD': Market(internal_pair='OGN', base='OGN', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=53, market_price=0.1655),
#  'RDNT/USD': Market(internal_pair='RDNT', base='RDNT', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=54, market_price=0.10311),
#  'ARK/USD': Market(internal_pair='ARK', base='ARK', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=55, market_price=0.79471),
#  'BNT/USD': Market(internal_pair='BNT', base='BNT', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=56, market_price=0.93812),
#  'CANTO/USD': Market(internal_pair='CANTO', base='CANTO', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=57, market_price=0.066),
#  'REQ/USD': Market(internal_pair='REQ', base='REQ', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=58, market_price=0.15027),
#  'BIGTIME/USD': Market(internal_pair='BIGTIME', base='BIGTIME', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=59, market_price=0.22841),
#  'KAS/USD': Market(internal_pair='KAS', base='KAS', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=60, market_price=0.16366),
#  'ORBS/USD': Market(internal_pair='ORBS', base='ORBS', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=61, market_price=0.039349),
#  'BLUR/USD': Market(internal_pair='BLUR', base='BLUR', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=62, market_price=0.43731),
#  'TIA/USD': Market(internal_pair='TIA', base='TIA', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=63, market_price=8.5964),
#  'BSV/USD': Market(internal_pair='BSV', base='BSV', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=64, market_price=85.128),
#  'ADA/USD': Market(internal_pair='ADA', base='ADA', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=65, market_price=1.2245),
#  'TON/USD': Market(internal_pair='TON', base='TON', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=66, market_price=6.9308),
#  'MINA/USD': Market(internal_pair='MINA', base='MINA', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=67, market_price=0.9228),
#  'POLYX/USD': Market(internal_pair='POLYX', base='POLYX', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=68, market_price=0.41162),
#  'GAS/USD': Market(internal_pair='GAS', base='GAS', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=69, market_price=6.8716),
#  'PENDLE/USD': Market(internal_pair='PENDLE', base='PENDLE', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=70, market_price=6.5219),
#  'STG/USD': Market(internal_pair='STG', base='STG', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=71, market_price=0.4377),
#  'FET/USD': Market(internal_pair='FET', base='FET', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=72, market_price=2.0761),
#  'STRAX/USD': Market(internal_pair='STRAX', base='STRAX', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=73, market_price=1.5829),
#  'NEAR/USD': Market(internal_pair='NEAR', base='NEAR', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=74, market_price=7.9969),
#  'MEME/USD': Market(internal_pair='MEME', base='MEME', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=75, market_price=0.017091),
#  'ORDI/USD': Market(internal_pair='ORDI', base='ORDI', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=76, market_price=47.795),
#  'BADGER/USD': Market(internal_pair='BADGER', base='BADGER', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=77, market_price=4.5656),
#  'NEO/USD': Market(internal_pair='NEO', base='NEO', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=78, market_price=21.735),
#  'ZEN/USD': Market(internal_pair='ZEN', base='ZEN', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=79, market_price=17.405),
#  'FIL/USD': Market(internal_pair='FIL', base='FIL', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=80, market_price=8.0998),
#  'PYTH/USD': Market(internal_pair='PYTH', base='PYTH', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=81, market_price=0.53328),
#  'SUSHI/USD': Market(internal_pair='SUSHI', base='SUSHI', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=82, market_price=1.5258),
#  'ILV/USD': Market(internal_pair='ILV', base='ILV', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=83, market_price=68.571),
#  'IMX/USD': Market(internal_pair='IMX', base='IMX', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=84, market_price=2.1585),
#  'kBONK/USD': Market(internal_pair='kBONK', base='kBONK', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=85, market_price=0.043326),
#  'GMT/USD': Market(internal_pair='GMT', base='GMT', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=86, market_price=0.24653),
#  'SUPER/USD': Market(internal_pair='SUPER', base='SUPER', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=87, market_price=1.7595),
#  'USTC/USD': Market(internal_pair='USTC', base='USTC', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=88, market_price=0.030288),
#  'NFTI/USD': Market(internal_pair='NFTI', base='NFTI', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=89, market_price=6.5609),
#  'JUP/USD': Market(internal_pair='JUP', base='JUP', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=90, market_price=1.3653),
#  'kLUNC/USD': Market(internal_pair='kLUNC', base='kLUNC', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=91, market_price=0.17128),
#  'RSR/USD': Market(internal_pair='RSR', base='RSR', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=92, market_price=0.018997),
#  'GALA/USD': Market(internal_pair='GALA', base='GALA', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=93, market_price=0.06143),
#  'JTO/USD': Market(internal_pair='JTO', base='JTO', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=94, market_price=3.7346),
#  'NTRN/USD': Market(internal_pair='NTRN', base='NTRN', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=95, market_price=0.64859),
#  'ACE/USD': Market(internal_pair='ACE', base='ACE', quote='USD', price_precision=0.0001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=96, market_price=3.511),
#  'MAV/USD': Market(internal_pair='MAV', base='MAV', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=97, market_price=0.31428),
#  'WIF/USD': Market(internal_pair='WIF', base='WIF', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=98, market_price=3.3337),
#  'CAKE/USD': Market(internal_pair='CAKE', base='CAKE', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=99, market_price=4.0616),
#  'PEOPLE/USD': Market(internal_pair='PEOPLE', base='PEOPLE', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=100, market_price=0.07311),
#  'ENS/USD': Market(internal_pair='ENS', base='ENS', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=101, market_price=42.154),
#  'ETC/USD': Market(internal_pair='ETC', base='ETC', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=102, market_price=37.285),
#  'XAI/USD': Market(internal_pair='XAI', base='XAI', quote='USD', price_precision=1e-05, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=103, market_price=0.42793),
#  'MANTA/USD': Market(internal_pair='MANTA', base='MANTA', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=104, market_price=1.2746),
#  'UMA/USD': Market(internal_pair='UMA', base='UMA', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=105, market_price=4.0347),
#  'ONDO/USD': Market(internal_pair='ONDO', base='ONDO', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=106, market_price=1.7519),
#  'ALT/USD': Market(internal_pair='ALT', base='ALT', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=107, market_price=0.19392),
#  'ZETA/USD': Market(internal_pair='ZETA', base='ZETA', quote='USD', price_precision=1e-05, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=108, market_price=0.90192),
#  'DYM/USD': Market(internal_pair='DYM', base='DYM', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=109, market_price=2.5449),
#  'MAVIA/USD': Market(internal_pair='MAVIA', base='MAVIA', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=110, market_price=2.2436),
#  'W/USD': Market(internal_pair='W', base='W', quote='USD', price_precision=1e-05, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=111, market_price=0.39724),
#  'PANDORA/USD': Market(internal_pair='PANDORA', base='PANDORA', quote='USD', price_precision=0.1, contract_precision=1e-05, contract_size=1.0, min_contracts=1e-05, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=112, market_price=3026.3),
#  'STRK/USD': Market(internal_pair='STRK', base='STRK', quote='USD', price_precision=1e-05, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=113, market_price=0.74914),
#  'PIXEL/USD': Market(internal_pair='PIXEL', base='PIXEL', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=114, market_price=0.28501),
#  'AI/USD': Market(internal_pair='AI', base='AI', quote='USD', price_precision=1e-05, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=115, market_price=0.8239),
#  'TAO/USD': Market(internal_pair='TAO', base='TAO', quote='USD', price_precision=0.01, contract_precision=0.001, contract_size=1.0, min_contracts=0.001, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=116, market_price=712.33),
#  'AR/USD': Market(internal_pair='AR', base='AR', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=117, market_price=27.782),
#  'MYRO/USD': Market(internal_pair='MYRO', base='MYRO', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=118, market_price=0.13148),
#  'kFLOKI/USD': Market(internal_pair='kFLOKI', base='kFLOKI', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=119, market_price=0.2394),
#  'BOME/USD': Market(internal_pair='BOME', base='BOME', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=120, market_price=0.01021),
#  'ETHFI/USD': Market(internal_pair='ETHFI', base='ETHFI', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=121, market_price=2.7899),
#  'ENA/USD': Market(internal_pair='ENA', base='ENA', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=122, market_price=0.95865),
#  'MNT/USD': Market(internal_pair='MNT', base='MNT', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=123, market_price=1.132),
#  'TNSR/USD': Market(internal_pair='TNSR', base='TNSR', quote='USD', price_precision=1e-05, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=124, market_price=0.70475),
#  'SAGA/USD': Market(internal_pair='SAGA', base='SAGA', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=125, market_price=2.7097),
#  'MERL/USD': Market(internal_pair='MERL', base='MERL', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=126, market_price=0.49245),
#  'HBAR/USD': Market(internal_pair='HBAR', base='HBAR', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=127, market_price=0.29865),
#  'POPCAT/USD': Market(internal_pair='POPCAT', base='POPCAT', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=128, market_price=1.3728),
#  'OMNI/USD': Market(internal_pair='OMNI', base='OMNI', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=129, market_price=14.099),
#  'EIGEN/USD': Market(internal_pair='EIGEN', base='EIGEN', quote='USD', price_precision=0.0001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=130, market_price=3.9825),
#  'REZ/USD': Market(internal_pair='REZ', base='REZ', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=131, market_price=0.06128),
#  'NOT/USD': Market(internal_pair='NOT', base='NOT', quote='USD', price_precision=1e-07, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=132, market_price=0.009721),
#  'TURBO/USD': Market(internal_pair='TURBO', base='TURBO', quote='USD', price_precision=1e-07, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=133, market_price=0.008693),
#  'BRETT/USD': Market(internal_pair='BRETT', base='BRETT', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=134, market_price=0.20036),
#  'IO/USD': Market(internal_pair='IO', base='IO', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=135, market_price=3.4698),
#  'ZK/USD': Market(internal_pair='ZK', base='ZK', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=136, market_price=0.23582),
#  'BLAST/USD': Market(internal_pair='BLAST', base='BLAST', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=137, market_price=0.012754),
#  'LISTA/USD': Market(internal_pair='LISTA', base='LISTA', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=138, market_price=0.61531),
#  'MEW/USD': Market(internal_pair='MEW', base='MEW', quote='USD', price_precision=1e-07, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=139, market_price=0.009582),
#  'RENDER/USD': Market(internal_pair='RENDER', base='RENDER', quote='USD', price_precision=0.001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=140, market_price=10.085),
#  'kDOGS/USD': Market(internal_pair='kDOGS', base='kDOGS', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=141, market_price=0.81328),
#  'POL/USD': Market(internal_pair='POL', base='POL', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=142, market_price=0.70693),
#  'CATI/USD': Market(internal_pair='CATI', base='CATI', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=143, market_price=0.5853),
#  'CELO/USD': Market(internal_pair='CELO', base='CELO', quote='USD', price_precision=0.0001, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=144, market_price=1.0625),
#  'HMSTR/USD': Market(internal_pair='HMSTR', base='HMSTR', quote='USD', price_precision=1e-07, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=145, market_price=0.004446),
#  'SCR/USD': Market(internal_pair='SCR', base='SCR', quote='USD', price_precision=1e-05, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=146, market_price=0.95931),
#  'NEIROETH/USD': Market(internal_pair='NEIROETH', base='NEIROETH', quote='USD', price_precision=1e-06, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=147, market_price=0.080833),
#  'kNEIRO/USD': Market(internal_pair='kNEIRO', base='kNEIRO', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=148, market_price=1.8045),
#  'GOAT/USD': Market(internal_pair='GOAT', base='GOAT', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=149, market_price=0.79319),
#  'MOODENG/USD': Market(internal_pair='MOODENG', base='MOODENG', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=150, market_price=0.47244),
#  'GRASS/USD': Market(internal_pair='GRASS', base='GRASS', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=151, market_price=3.0675),
#  'PURR/USD': Market(internal_pair='PURR', base='PURR', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=152, market_price=0.25505),
#  'PNUT/USD': Market(internal_pair='PNUT', base='PNUT', quote='USD', price_precision=0.0001, contract_precision=0.1, contract_size=1.0, min_contracts=0.1, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=153, market_price=1.3989),
#  'XLM/USD': Market(internal_pair='XLM', base='XLM', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=154, market_price=0.4912),
#  'CHILLGUY/USD': Market(internal_pair='CHILLGUY', base='CHILLGUY', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=155, market_price=0.4676),
#  'SAND/USD': Market(internal_pair='SAND', base='SAND', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=156, market_price=0.93988),
#  'IOTA/USD': Market(internal_pair='IOTA', base='IOTA', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=157, market_price=0.4828),
#  'ALGO/USD': Market(internal_pair='ALGO', base='ALGO', quote='USD', price_precision=1e-05, contract_precision=1.0, contract_size=1.0, min_contracts=1.0, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=158, market_price=0.4797),
#  'HYPE/USD': Market(internal_pair='HYPE', base='HYPE', quote='USD', price_precision=0.001, contract_precision=0.01, contract_size=1.0, min_contracts=0.01, max_contracts=inf, min_cost=10.0, max_cost=inf, coin_index=159, market_price=12.751)}

# %%
df = await ex.get_last_ohlcv("BTC/USD", "4h", limit=100)
df
# Out:
#                          open      high       low     close      volume
# date
# 2024-11-19 04:00:00   91530.0   92154.0   91314.0   91721.0   879.51607
# 2024-11-19 08:00:00   91724.0   92043.0   91281.0   91753.0   602.08539
# 2024-11-19 12:00:00   91750.0   92948.0   91061.0   92490.0  2070.59951
# 2024-11-19 16:00:00   92481.0   94000.0   92238.0   93305.0  2076.23251
# 2024-11-19 20:00:00   93310.0   93667.0   91351.0   92366.0  2486.32902
# ...                       ...       ...       ...       ...         ...
# 2024-12-05 00:00:00   98666.0  104940.0   97939.0  103100.0  9673.92963
# 2024-12-05 04:00:00  103099.0  103740.0  101474.0  102400.0  3881.20232
# 2024-12-05 08:00:00  102410.0  103395.0  102388.0  102710.0  1866.70872
# 2024-12-05 12:00:00  102709.0  103772.0  100901.0  101364.0  5428.01772
# 2024-12-05 16:00:00  101378.0  102230.0  100573.0  101119.0  4290.86108
#
# [100 rows x 5 columns]

# %%
df["rsi"] = ta.momentum.rsi(df["close"], 14)
df
# Out:
#                          open      high       low     close      volume  \
# date
# 2024-11-19 04:00:00   91530.0   92154.0   91314.0   91721.0   879.51607
# 2024-11-19 08:00:00   91724.0   92043.0   91281.0   91753.0   602.08539
# 2024-11-19 12:00:00   91750.0   92948.0   91061.0   92490.0  2070.59951
# 2024-11-19 16:00:00   92481.0   94000.0   92238.0   93305.0  2076.23251
# 2024-11-19 20:00:00   93310.0   93667.0   91351.0   92366.0  2486.32902
# ...                       ...       ...       ...       ...         ...
# 2024-12-05 00:00:00   98666.0  104940.0   97939.0  103100.0  9673.92963
# 2024-12-05 04:00:00  103099.0  103740.0  101474.0  102400.0  3881.20232
# 2024-12-05 08:00:00  102410.0  103395.0  102388.0  102710.0  1866.70872
# 2024-12-05 12:00:00  102709.0  103772.0  100901.0  101364.0  5428.01772
# 2024-12-05 16:00:00  101378.0  102230.0  100573.0  101119.0  4290.86108
#
#                            rsi
# date
# 2024-11-19 04:00:00        NaN
# 2024-11-19 08:00:00        NaN
# 2024-11-19 12:00:00        NaN
# 2024-11-19 16:00:00        NaN
# 2024-11-19 20:00:00        NaN
# ...                        ...
# 2024-12-05 00:00:00  76.359750
# 2024-12-05 04:00:00  72.094959
# 2024-12-05 08:00:00  72.818974
# 2024-12-05 12:00:00  64.940398
# 2024-12-05 16:00:00  63.591716
#
# [100 rows x 6 columns]

# %%
usd = await ex.get_balance()
print(usd)
# Out:
# total=2008.169665 free=2008.169665 used=0.0

# %%
positions = await ex.get_open_positions(pairs=["BTC/USD"])
print(positions)
# Out:
# []

# %%
rsi = 80
btc_price = 100000

if len(positions) > 0:
    if rsi < 70:
        order = await ex.place_order("BTC/USD", "sell", None, positions[0].size, "market", True)
        print(order)

elif len(positions) == 0:
    if rsi > 70:
        order = await ex.place_order("BTC/USD", "buy", None, (usd.total * 0.1) / btc_price, "market", False)
        print(order)
# Out:
# id='52994325784' pair='BTC/USD' type='limit' side='sell' price=101216.0 size=0.002 reduce=False filled=0.002 remaining=0.0 timestamp=1733421284194

# %%
ex = PerpHyperliquid(
    public_adress="",
    private_key="",
)
await ex.load_markets()

df = await ex.get_last_ohlcv("BTC/USD", "4h", limit=100)

df["rsi"] = ta.momentum.rsi(df["close"], 14)

print(df.iloc[-5:])

usd = await ex.get_balance()

print(f"Balance: {usd.total} USD")

positions = await ex.get_open_positions(pairs=["BTC/USD"])

btc_price = df.iloc[-1]["close"]
rsi = df.iloc[-2]["rsi"]

if len(positions) > 0:
    if rsi < 60:
        order = await ex.place_order("BTC/USD", "sell", None, positions[0].size, "market", True)
        print(order)

elif len(positions) == 0:
    if rsi > 60:
        order = await ex.place_order("BTC/USD", "buy", None, (usd.total * 0.1) / btc_price, "market", False)
        print(order)

await ex.close()
# Out:
#                          open      high       low     close      volume  \
# date
# 2024-12-05 00:00:00   98666.0  104940.0   97939.0  103100.0  9673.92963
# 2024-12-05 04:00:00  103099.0  103740.0  101474.0  102400.0  3881.20232
# 2024-12-05 08:00:00  102410.0  103395.0  102388.0  102710.0  1866.70872
# 2024-12-05 12:00:00  102709.0  103772.0  100901.0  101364.0  5428.01772
# 2024-12-05 16:00:00  101378.0  102230.0  100573.0  101400.0  4589.10899
#
#                            rsi
# date
# 2024-12-05 00:00:00  76.359750
# 2024-12-05 04:00:00  72.094959
# 2024-12-05 08:00:00  72.818974
# 2024-12-05 12:00:00  64.940398
# 2024-12-05 16:00:00  65.049316
# Balance: 2007.924297 USD
