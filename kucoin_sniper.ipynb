# %% [markdown]
# <a href="https://colab.research.google.com/github/CryptoRobotFr/General-code-trading-bot/blob/main/kucoin_sniper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ccxt

# %%
import ccxt
import time

class SpotKucoin():
    def __init__(self, apiKey=None, secret=None, password=None):
        kucoinAuthObject = {
            "apiKey": apiKey,
            "secret": secret,
            "password": password,
        }
        if kucoinAuthObject['secret'] == None:
            self._auth = False
            self._session = ccxt.kucoin()
        else:
            self._auth = True
            self._session = ccxt.kucoin(kucoinAuthObject)
        self.market = self._session.load_markets()

    def reload_markets(self):
        self.market = self._session.load_markets()

    def authentication_required(fn):
        """Annotation for methods that require auth."""
        def wrapped(self, *args, **kwargs):
            if not self._auth:
                print("You must be authenticated to use this method", fn)
                exit()
            else:
                return fn(self, *args, **kwargs)
        return wrapped

    def convert_amount_to_precision(self, symbol, amount):
        return self._session.amount_to_precision(symbol, amount)

    def convert_price_to_precision(self, symbol, price):
        return self._session.price_to_precision(symbol, price)

    @authentication_required
    def place_market_order(self, symbol, side, amount):
        try:
            return self._session.createOrder(
                symbol, 
                'market', 
                side, 
                self.convert_amount_to_precision(symbol, amount),
                None
            )
        except Exception as err:
            raise err

    @authentication_required
    def place_limit_order(self, symbol, side, amount, price):
        try:
            return self._session.createOrder(
                symbol, 
                'limit', 
                side, 
                self.convert_amount_to_precision(symbol, amount), 
                self.convert_price_to_precision(symbol, price)
                )
        except Exception as err:
            raise err

kucoin = SpotKucoin(
    apiKey="",
    secret="",
    password=""
)

symbol = "BTC/USDT"
amount = 10
# buy_price = 20000
# sell_price = 25000
seconds_before_sell = 30

while True:
    try:
        # amount += 0.0000001
        kucoin.reload_markets()

        kucoin.place_market_order(symbol, "buy", amount)
        # kucoin.place_limit_order(symbol, "buy", amount, price)
        print("Buy Order success!")

        print("Waiting for sell...")
        time.sleep(seconds_before_sell)

        kucoin.place_market_order(symbol, "sell", amount)
        # kucoin.place_limit_order(symbol, "sell", amount, price)
        print("Sell Order success!")

        break
    except Exception as err:
        print(err)
        if str(err) == "kucoin does not have market symbol " + symbol:
            time.sleep(0.2)
        pass
# Out:
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# kucoin requires "apiKey" credential
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a63b97a6eadb> in <module>()
#      79         kucoin.reload_markets()
#      80
# ---> 81         kucoin.place_market_order(symbol, "buy", amount)
#      82         # kucoin.place_limit_order(symbol, "buy", amount, price)
#      83         print("Buy Order success!")
#
# <ipython-input-3-a63b97a6eadb> in wrapped(self, *args, **kwargs)
#      27                 exit()
#      28             else:
# ---> 29                 return fn(self, *args, **kwargs)
#      30         return wrapped
#      31
#
# <ipython-input-3-a63b97a6eadb> in place_market_order(self, symbol, side, amount)
#      44                 side,
#      45                 self.convert_amount_to_precision(symbol, amount),
# ---> 46                 None
#      47             )
#      48         except Exception as err:
#
# /usr/local/lib/python3.7/dist-packages/ccxt/kucoin.py in create_order(self, symbol, type, side, amount, price, params)
#    1247         elif tradeType == 'MARGIN_TRADE':
#    1248             method = 'privatePostMarginOrder'
# -> 1249         response = getattr(self, method)(self.extend(request, params))
#    1250         #
#    1251         #     {
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in inner(_self, params, context)
#     495                 if context is not None:
#     496                     inner_kwargs['context'] = params
# --> 497                 return entry(_self, **inner_kwargs)
#     498             return inner
#     499         to_bind = partialer()
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in request(self, path, api, method, params, headers, body, config, context)
#    2622
#    2623     def request(self, path, api='public', method='GET', params={}, headers=None, body=None, config={}, context={}):
# -> 2624         return self.fetch2(path, api, method, params, headers, body, config, context)
#    2625
#    2626     def load_accounts(self, reload=False, params={}):
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body, config, context)
#    2616         if self.enableRateLimit:
#    2617             cost = self.calculate_rate_limiter_cost(api, method, path, params, config, context)
# -> 2618             self.throttle(cost)
#    2619         self.lastRestRequestTimestamp = self.milliseconds()
#    2620         request = self.sign(path, api, method, params, headers, body)
#
# /usr/local/lib/python3.7/dist-packages/ccxt/base/exchange.py in throttle(self, cost)
#     530         if elapsed < sleep_time:
#     531             delay = sleep_time - elapsed
# --> 532             time.sleep(delay / 1000.0)
#     533
#     534     @staticmethod
#
# KeyboardInterrupt:
